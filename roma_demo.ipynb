# %%
from auxiliary_scripts.flow_provider import RoMaFlowProvider
from utils import load_config

config = load_config("configs/epipolar/mft/mft_roma_direct_ransac_zaragoza_pose_correspondence_sampling.py")
flow_provider = RoMaFlowProvider(config.MFT_backbone_cfg, config=config)

# %%
from dataset_utils.bop_challenge import get_bop_image_tensor
from pathlib import Path

image_template_path = Path('/ment/personal/jelint19/data/bop/hope/onboarding_static/obj_000015_up/rgb/000007.jpg')
image_target_path = Path('/ment/personal/jelint19/data/bop/hope/val/000002/rgb/000000.png')

image_template = get_bop_image_tensor(image_template_path)
image_target = get_bop_image_tensor(image_target_path)
